# %% [markdown]
# # 垂直联邦XGB (MPC XGBoost)
#
# > 以下代码仅供演示。出于系统安全考虑，请 **不要** 直接用于生产。

# %%
from sklearn.metrics import roc_auc_score

import secretflow as sf
from secretflow.data import FedNdarray, PartitionWay
from secretflow.device.driver import reveal
from secretflow.ml.boost.ss_xgb_v import Xgb
import pprint

pp = pprint.PrettyPrinter(depth=4)

# Check the version of your SecretFlow
print('The version of SecretFlow: {}'.format(sf.__version__))
# Out:
# The version of SecretFlow: 1.7.0b0

# %%
# process_utils.py
import psutil
import os
import platform


def find_process_by_port(port):
    for proc in psutil.process_iter(["pid", "name"]):
        try:
            connections = proc.connections(kind="inet")
            for conn in connections:
                if conn.laddr.port == port:
                    return proc.pid
        except (psutil.AccessDenied, psutil.NoSuchProcess):
            continue
    return None


def kill_process(pid):
    try:
        if platform.system() == "Windows":
            os.system(f"taskkill /PID {pid} /F")
        else:
            os.system(f"kill -9 {pid}")
        print(f"Process with PID {pid} has been terminated.")
    except Exception as e:
        print(f"Error terminating process with PID {pid}: {e}")


def kill_port_process(port: int):
    pid = find_process_by_port(port)

    if pid:
        print(f"Process found using port {port}: PID {pid}")
        kill_process(pid)
    else:
        print(f"No process found using port {port}")


pyu_port = 16307
spu_port = 11666

kill_port_process(port=pyu_port)
kill_port_process(port=spu_port)

import secretflow as sf

# Check the version of your SecretFlow
print("The version of SecretFlow: {}".format(sf.__version__))

# In case you have a running secretflow runtime already.
sf.shutdown()

pyu_port = 16307
spu_port = 11666


cluster_config = {
    "parties": {
        "alice": {
            # replace with alice's real address.
            "address": "ecm-01:" + str(pyu_port),
            "listen_addr": "0.0.0.0:" + str(pyu_port),
        },
        "bob": {
            # replace with bob's real address.
            "address": "ecm-02:" + str(pyu_port),
            "listen_addr": "0.0.0.0:" + str(pyu_port),
        },
    },
    "self_party": "alice",
}

tls_config = {
    "ca_cert": "/home/beng003/certificate/bob_ca.crt",
    "cert": "/home/beng003/certificate/alice_server_cert.crt",
    "key": "/home/beng003/certificate/alice_server_key.key",
}


sf.init(address="ecm-01:6379", cluster_config=cluster_config, tls_config=tls_config)
alice = sf.PYU("alice")
bob = sf.PYU("bob")
print("Alice and Bob are ready to go!")

import spu

cluster_def = {
    "nodes": [
        {
            "party": "alice",
            # The address for other peers.
            "address": "ecm-01:" + str(spu_port),
            # The listen address of this node.
            # Optional. Address will be used if listen_address is empty.
            "listen_address": "0.0.0.0:" + str(spu_port),
        },
        {
            "party": "bob",
            "address": "ecm-02:" + str(spu_port),
            "listen_address": "0.0.0.0:" + str(spu_port),
        },
    ],
    "runtime_config": {
        "protocol": spu.spu_pb2.SEMI2K,
        "field": spu.spu_pb2.FM128,
        "sigmoid_mode": spu.spu_pb2.RuntimeConfig.SIGMOID_REAL,
    },
}

link_desc = {
    "recv_timeout_ms": 6000,
}

spu_device = sf.SPU(cluster_def=cluster_def, link_desc=link_desc)
print("*****************************************************Alice SPU")
# Out:
# /tmp/ipykernel_923696/1211501630.py:10: DeprecationWarning: connections() is deprecated and will be removed; use net_connections() instead
#   connections = proc.connections(kind="inet")
# No process found using port 16307
# No process found using port 11666
# The version of SecretFlow: 1.7.0b0
# 2024-08-03 16:37:49,664	INFO worker.py:1540 -- Connecting to existing Ray cluster at address: ecm-01:6379...
# 2024-08-03 16:37:49,681	INFO worker.py:1724 -- Connected to Ray cluster.
# 2024-08-03 16:37:49.721 INFO api.py:233 [alice] -- [Anonymous_job] Started rayfed with {'CLUSTER_ADDRESSES': {'alice': '0.0.0.0:16307', 'bob': 'ecm-02:16307'}, 'CURRENT_PARTY_NAME': 'alice', 'TLS_CONFIG': {'ca_cert': '/home/beng003/certificate/bob_ca.crt', 'cert': '/home/beng003/certificate/alice_server_cert.crt', 'key': '/home/beng003/certificate/alice_server_key.key'}}
# 2024-08-03 16:37:51.146 INFO barriers.py:284 [alice] -- [Anonymous_job] Succeeded to create receiver proxy actor.
# (ReceiverProxyActor pid=938319) 2024-08-03 16:37:51.140 INFO grpc_proxy.py:359 [alice] -- [Anonymous_job] ReceiverProxy binding port 16307, options: (('grpc.enable_retries', 1), ('grpc.so_reuseport', 0), ('grpc.max_send_message_length', 524288000), ('grpc.max_receive_message_length', 524288000), ('grpc.service_config', '{"methodConfig": [{"name": [{"service": "GrpcService"}], "retryPolicy": {"maxAttempts": 5, "initialBackoff": "5s", "maxBackoff": "30s", "backoffMultiplier": 2, "retryableStatusCodes": ["UNAVAILABLE"]}}]}'))...
# (ReceiverProxyActor pid=938319) 2024-08-03 16:37:51.145 INFO grpc_proxy.py:379 [alice] -- [Anonymous_job] Successfully start Grpc service with credentials.
# 2024-08-03 16:37:52.193 INFO barriers.py:333 [alice] -- [Anonymous_job] SenderProxyActor has successfully created.
# 2024-08-03 16:37:52.194 INFO barriers.py:520 [alice] -- [Anonymous_job] Try ping ['bob'] at 0 attemp, up to 3600 attemps.
# Alice and Bob are ready to go!
# *****************************************************Alice SPU
# (raylet) [2024-08-03 17:29:21,153 E 16009 16009] (raylet) node_manager.cc:3024: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 47b2c7b94af672612aced3c2e8a79c833f7f9db594029492d2e7085e, IP: ecm-01) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip ecm-01`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-08-03 17:31:21,156 E 16009 16009] (raylet) node_manager.cc:3024: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 47b2c7b94af672612aced3c2e8a79c833f7f9db594029492d2e7085e, IP: ecm-01) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip ecm-01`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-08-03 17:34:21,160 E 16009 16009] (raylet) node_manager.cc:3024: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 47b2c7b94af672612aced3c2e8a79c833f7f9db594029492d2e7085e, IP: ecm-01) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip ecm-01`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-08-03 17:37:21,165 E 16009 16009] (raylet) node_manager.cc:3024: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 47b2c7b94af672612aced3c2e8a79c833f7f9db594029492d2e7085e, IP: ecm-01) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip ecm-01`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (raylet) [2024-08-03 17:39:21,169 E 16009 16009] (raylet) node_manager.cc:3024: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: 47b2c7b94af672612aced3c2e8a79c833f7f9db594029492d2e7085e, IP: ecm-01) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip ecm-01`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.

# %% [markdown]
# ## 数据准备
#
# 我们将准备一个垂直数据集。

# %%
from sklearn.datasets import load_breast_cancer

ds = load_breast_cancer()
x, y = ds['data'], ds['target']

v_data = FedNdarray(
    {
        alice: (alice(lambda: x[:, :15])()),
        bob: (bob(lambda: x[:, 15:])()),
    },
    partition_way=PartitionWay.VERTICAL,
)
label_data = FedNdarray(
    {alice: (alice(lambda: y)())},
    partition_way=PartitionWay.VERTICAL,
)

# %%
import pandas as pd

df = pd.DataFrame(ds['data'], columns=ds["feature_names"])
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 0                   0.07871  ...        25.380          17.33
# 1                   0.05667  ...        24.990          23.41
# 2                   0.05999  ...        23.570          25.53
# 3                   0.09744  ...        14.910          26.50
# 4                   0.05883  ...        22.540          16.67
# ..                      ...  ...           ...            ...
# 564                 0.05623  ...        25.450          26.40
# 565                 0.05533  ...        23.690          38.25
# 566                 0.05648  ...        18.980          34.12
# 567                 0.07016  ...        25.740          39.42
# 568                 0.05884  ...         9.456          30.37
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 0             184.60      2019.0           0.16220            0.66560
# 1             158.80      1956.0           0.12380            0.18660
# 2             152.50      1709.0           0.14440            0.42450
# 3              98.87       567.7           0.20980            0.86630
# 4             152.20      1575.0           0.13740            0.20500
# ..               ...         ...               ...                ...
# 564           166.10      2027.0           0.14100            0.21130
# 565           155.00      1731.0           0.11660            0.19220
# 566           126.70      1124.0           0.11390            0.30940
# 567           184.60      1821.0           0.16500            0.86810
# 568            59.16       268.6           0.08996            0.06444
#
#      worst concavity  worst concave points  worst symmetry  \
# 0             0.7119                0.2654          0.4601
# 1             0.2416                0.1860          0.2750
# 2             0.4504                0.2430          0.3613
# 3             0.6869                0.2575          0.6638
# 4             0.4000                0.1625          0.2364
# ..               ...                   ...             ...
# 564           0.4107                0.2216          0.2060
# 565           0.3215                0.1628          0.2572
# 566           0.3403                0.1418          0.2218
# 567           0.9387                0.2650          0.4087
# 568           0.0000                0.0000          0.2871
#
#      worst fractal dimension
# 0                    0.11890
# 1                    0.08902
# 2                    0.08758
# 3                    0.17300
# 4                    0.07678
# ..                       ...
# 564                  0.07115
# 565                  0.06637
# 566                  0.07820
# 567                  0.12400
# 568                  0.07039
#
# [569 rows x 30 columns]

# %% [markdown]
# ### 参数准备

# %%
params = {
    "num_boost_round": 10,  # Number of boosting iterations, default is 10
    "max_depth": 5,  # Maximum depth of a tree, default is 5
    "learning_rate": 0.3,  # Step size shrinkage, default is 0.3
    "objective": "logistic",  # Learning objective, default is 'logistic'
    "reg_lambda": 0.1,  # L2 regularization term, default is 0.1
    "subsample": 1,  # Subsample ratio of the training instances, default is 1
    "colsample_by_tree": 1,  # Subsample ratio of columns, default is 1
    "sketch_eps": 0.1,  # Number of bins for sketching, default is 0.1
    "base_score": 0,  # Initial prediction score, default is 0
    "seed": 42,  # Pseudorandom number generator seed, default is 42
}
pp.pprint(params)
# Out:
# {'base_score': 0,
#  'colsample_by_tree': 1,
#  'learning_rate': 0.3,
#  'max_depth': 5,
#  'num_boost_round': 10,
#  'objective': 'logistic',
#  'reg_lambda': 0.1,
#  'seed': 42,
#  'sketch_eps': 0.1,
#  'subsample': 1}

# %% [markdown]
# ## 运行 Xgb
#
# 我们使用 spu 设备创建一个 Xgb 对象，并拟合数据。

# %%
xgb = Xgb(spu_device)
model = xgb.train(params, v_data, label_data)
# Out:
# 2024-08-03 16:38:25.315 INFO proxy.py:180 [alice] -- [Anonymous_job] Create proxy actor <class 'secretflow.ml.boost.ss_xgb_v.core.tree_worker.XgbTreeWorker'> with party alice.
# 2024-08-03 16:38:25.355 INFO proxy.py:180 [alice] -- [Anonymous_job] Create proxy actor <class 'secretflow.ml.boost.ss_xgb_v.core.tree_worker.XgbTreeWorker'> with party bob.
# 2024-08-03 16:38:25.357 INFO booster.py:167 [alice] -- [Anonymous_job] fragment_count 1
# 2024-08-03 16:38:27.011 INFO booster.py:185 [alice] -- [Anonymous_job] prepare time 2.946911334991455s
# 2024-08-03 16:38:27.188 INFO booster.py:198 [alice] -- [Anonymous_job] global_setup time 0.17596864700317383s
# 2024-08-03 16:38:33.430 INFO booster.py:217 [alice] -- [Anonymous_job] build & infeed bucket_map fragments [0, 0]
# 2024-08-03 16:38:33.431 INFO booster.py:220 [alice] -- [Anonymous_job] build & infeed bucket_map time 6.2414374351501465s
# 2024-08-03 16:38:33.569 INFO booster.py:233 [alice] -- [Anonymous_job] init_pred time 0.13740897178649902s
# 2024-08-03 16:38:33.625 INFO booster.py:375 [alice] -- [Anonymous_job] epoch 0 tree_setup time 0.0547482967376709s
# 2024-08-03 16:38:36.388 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 2.7585842609405518s
# 2024-08-03 16:38:37.849 INFO booster.py:486 [alice] -- [Anonymous_job] level 0 time 4.219235181808472s
# 2024-08-03 16:38:42.823 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 4.973064184188843s
# 2024-08-03 16:38:45.732 INFO booster.py:486 [alice] -- [Anonymous_job] level 1 time 7.88231635093689s
# 2024-08-03 16:38:55.646 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 9.912849426269531s
# 2024-08-03 16:39:00.473 INFO booster.py:486 [alice] -- [Anonymous_job] level 2 time 14.739202976226807s
# 2024-08-03 16:39:20.231 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 19.756935119628906s
# 2024-08-03 16:39:29.665 INFO booster.py:486 [alice] -- [Anonymous_job] level 3 time 29.191286325454712s
# 2024-08-03 16:40:09.862 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 40.195913314819336s
# 2024-08-03 16:40:28.980 INFO booster.py:486 [alice] -- [Anonymous_job] level 4 time 59.31370687484741s
# 2024-08-03 16:40:29.320 WARNING callback.py:455 [alice] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:40:30.715 INFO booster.py:392 [alice] -- [Anonymous_job] epoch 0 time 117.0891661643982s
# 2024-08-03 16:40:31.280 INFO booster.py:375 [alice] -- [Anonymous_job] epoch 1 tree_setup time 0.5636065006256104s
# 2024-08-03 16:40:36.495 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.209891319274902s
# 2024-08-03 16:40:38.330 INFO booster.py:486 [alice] -- [Anonymous_job] level 0 time 7.045055150985718s
# 2024-08-03 16:40:43.491 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.1596455574035645s
# 2024-08-03 16:40:45.992 INFO booster.py:486 [alice] -- [Anonymous_job] level 1 time 7.661035776138306s
# 2024-08-03 16:40:56.420 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 10.42656397819519s
# 2024-08-03 16:41:02.196 INFO booster.py:486 [alice] -- [Anonymous_job] level 2 time 16.20238995552063s
# 2024-08-03 16:41:22.721 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 20.523929834365845s
# 2024-08-03 16:41:30.917 INFO booster.py:486 [alice] -- [Anonymous_job] level 3 time 28.720407009124756s
# 2024-08-03 16:42:11.127 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 40.20853114128113s
# 2024-08-03 16:42:29.204 INFO booster.py:486 [alice] -- [Anonymous_job] level 4 time 58.286137342453s
# 2024-08-03 16:42:29.825 WARNING callback.py:455 [alice] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:42:31.345 INFO booster.py:392 [alice] -- [Anonymous_job] epoch 1 time 120.06440615653992s
# 2024-08-03 16:42:31.919 INFO booster.py:375 [alice] -- [Anonymous_job] epoch 2 tree_setup time 0.5726900100708008s
# 2024-08-03 16:42:36.828 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 4.903411388397217s
# 2024-08-03 16:42:38.654 INFO booster.py:486 [alice] -- [Anonymous_job] level 0 time 6.729125499725342s
# 2024-08-03 16:42:43.918 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.2631285190582275s
# 2024-08-03 16:42:46.779 INFO booster.py:486 [alice] -- [Anonymous_job] level 1 time 8.123968362808228s
# 2024-08-03 16:42:56.801 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 10.021292924880981s
# 2024-08-03 16:43:01.164 INFO booster.py:486 [alice] -- [Anonymous_job] level 2 time 14.384777784347534s
# 2024-08-03 16:43:21.220 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 20.053566455841064s
# 2024-08-03 16:43:30.402 INFO booster.py:486 [alice] -- [Anonymous_job] level 3 time 29.235790729522705s
# 2024-08-03 16:44:10.304 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 39.901440382003784s
# 2024-08-03 16:44:28.945 INFO booster.py:486 [alice] -- [Anonymous_job] level 4 time 58.542325019836426s
# 2024-08-03 16:44:29.557 WARNING callback.py:455 [alice] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:44:30.629 INFO booster.py:392 [alice] -- [Anonymous_job] epoch 2 time 118.70876145362854s
# 2024-08-03 16:44:31.257 INFO booster.py:375 [alice] -- [Anonymous_job] epoch 3 tree_setup time 0.6269352436065674s
# 2024-08-03 16:44:36.330 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.067467927932739s
# 2024-08-03 16:44:37.524 INFO booster.py:486 [alice] -- [Anonymous_job] level 0 time 6.261472702026367s
# 2024-08-03 16:44:42.454 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 4.929500341415405s
# 2024-08-03 16:44:44.728 INFO booster.py:486 [alice] -- [Anonymous_job] level 1 time 7.203836917877197s
# 2024-08-03 16:44:54.463 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 9.733672857284546s
# 2024-08-03 16:44:59.597 INFO booster.py:486 [alice] -- [Anonymous_job] level 2 time 14.866980075836182s
# 2024-08-03 16:45:19.900 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 20.302722454071045s
# 2024-08-03 16:45:28.890 INFO booster.py:486 [alice] -- [Anonymous_job] level 3 time 29.291829586029053s
# 2024-08-03 16:46:09.510 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 40.61919403076172s
# 2024-08-03 16:46:28.476 INFO booster.py:486 [alice] -- [Anonymous_job] level 4 time 59.58522272109985s
# 2024-08-03 16:46:29.032 WARNING callback.py:455 [alice] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:46:30.180 INFO booster.py:392 [alice] -- [Anonymous_job] epoch 3 time 118.9226987361908s
# 2024-08-03 16:46:30.563 INFO booster.py:375 [alice] -- [Anonymous_job] epoch 4 tree_setup time 0.38097667694091797s
# 2024-08-03 16:46:35.486 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 4.917954444885254s
# 2024-08-03 16:46:36.819 INFO booster.py:486 [alice] -- [Anonymous_job] level 0 time 6.251402139663696s
# 2024-08-03 16:46:41.912 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.092152833938599s
# 2024-08-03 16:46:44.127 INFO booster.py:486 [alice] -- [Anonymous_job] level 1 time 7.306932687759399s
# 2024-08-03 16:46:53.694 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 9.565669298171997s
# 2024-08-03 16:46:58.646 INFO booster.py:486 [alice] -- [Anonymous_job] level 2 time 14.517317295074463s
# 2024-08-03 16:47:18.499 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 19.852324724197388s
# 2024-08-03 16:47:27.745 INFO booster.py:486 [alice] -- [Anonymous_job] level 3 time 29.098330974578857s
# 2024-08-03 16:48:10.621 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 42.87535357475281s
# 2024-08-03 16:48:28.860 INFO booster.py:486 [alice] -- [Anonymous_job] level 4 time 61.11416268348694s
# 2024-08-03 16:48:29.468 WARNING callback.py:455 [alice] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:48:30.819 INFO booster.py:392 [alice] -- [Anonymous_job] epoch 4 time 120.25512862205505s
# 2024-08-03 16:48:31.183 INFO booster.py:375 [alice] -- [Anonymous_job] epoch 5 tree_setup time 0.36281299591064453s
# 2024-08-03 16:48:36.332 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.144068241119385s
# 2024-08-03 16:48:38.198 INFO booster.py:486 [alice] -- [Anonymous_job] level 0 time 7.010040521621704s
# 2024-08-03 16:48:42.965 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 4.7658092975616455s
# 2024-08-03 16:48:46.110 INFO booster.py:486 [alice] -- [Anonymous_job] level 1 time 7.910849094390869s
# 2024-08-03 16:48:55.539 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 9.427154302597046s
# 2024-08-03 16:49:01.114 INFO booster.py:486 [alice] -- [Anonymous_job] level 2 time 15.002279996871948s
# 2024-08-03 16:49:21.068 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 19.95311450958252s
# 2024-08-03 16:49:29.559 INFO booster.py:486 [alice] -- [Anonymous_job] level 3 time 28.44417142868042s
# 2024-08-03 16:50:09.723 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 40.162930965423584s
# 2024-08-03 16:50:28.457 INFO booster.py:486 [alice] -- [Anonymous_job] level 4 time 58.896870851516724s
# 2024-08-03 16:50:28.813 WARNING callback.py:455 [alice] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:50:29.895 INFO booster.py:392 [alice] -- [Anonymous_job] epoch 5 time 118.7112090587616s
# 2024-08-03 16:50:30.465 INFO booster.py:375 [alice] -- [Anonymous_job] epoch 6 tree_setup time 0.5683789253234863s
# 2024-08-03 16:50:35.632 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.161942720413208s
# 2024-08-03 16:50:37.399 INFO booster.py:486 [alice] -- [Anonymous_job] level 0 time 6.928584575653076s
# 2024-08-03 16:50:42.606 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.2056565284729s
# 2024-08-03 16:50:45.077 INFO booster.py:486 [alice] -- [Anonymous_job] level 1 time 7.676584005355835s
# 2024-08-03 16:50:55.300 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 10.222363471984863s
# 2024-08-03 16:51:00.118 INFO booster.py:486 [alice] -- [Anonymous_job] level 2 time 15.040531396865845s
# 2024-08-03 16:51:19.988 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 19.869152307510376s
# 2024-08-03 16:51:28.990 INFO booster.py:486 [alice] -- [Anonymous_job] level 3 time 28.87057375907898s
# 2024-08-03 16:52:10.100 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 41.109726428985596s
# 2024-08-03 16:52:26.851 INFO booster.py:486 [alice] -- [Anonymous_job] level 4 time 57.85997200012207s
# 2024-08-03 16:52:27.459 WARNING callback.py:455 [alice] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:52:28.339 INFO booster.py:392 [alice] -- [Anonymous_job] epoch 6 time 117.8733377456665s
# 2024-08-03 16:52:28.910 INFO booster.py:375 [alice] -- [Anonymous_job] epoch 7 tree_setup time 0.5694584846496582s
# 2024-08-03 16:52:34.487 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.572624206542969s
# 2024-08-03 16:52:35.856 INFO booster.py:486 [alice] -- [Anonymous_job] level 0 time 6.941307306289673s
# 2024-08-03 16:52:40.614 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 4.757378578186035s
# 2024-08-03 16:52:43.303 INFO booster.py:486 [alice] -- [Anonymous_job] level 1 time 7.446256160736084s
# 2024-08-03 16:52:53.270 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 9.965532064437866s
# 2024-08-03 16:52:57.689 INFO booster.py:486 [alice] -- [Anonymous_job] level 2 time 14.385309219360352s
# 2024-08-03 16:53:17.393 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 19.702075242996216s
# 2024-08-03 16:53:25.702 INFO booster.py:486 [alice] -- [Anonymous_job] level 3 time 28.01028275489807s
# 2024-08-03 16:54:08.294 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 42.59149432182312s
# 2024-08-03 16:54:25.544 INFO booster.py:486 [alice] -- [Anonymous_job] level 4 time 59.8415641784668s
# 2024-08-03 16:54:26.143 WARNING callback.py:455 [alice] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:54:30.099 INFO booster.py:392 [alice] -- [Anonymous_job] epoch 7 time 121.18871569633484s
# 2024-08-03 16:54:30.664 INFO booster.py:375 [alice] -- [Anonymous_job] epoch 8 tree_setup time 0.5638189315795898s
# 2024-08-03 16:54:35.626 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 4.956108093261719s
# 2024-08-03 16:54:36.906 INFO booster.py:486 [alice] -- [Anonymous_job] level 0 time 6.236189842224121s
# 2024-08-03 16:54:41.792 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 4.885135650634766s
# 2024-08-03 16:54:44.274 INFO booster.py:486 [alice] -- [Anonymous_job] level 1 time 7.36713719367981s
# 2024-08-03 16:54:54.128 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 9.852665185928345s
# 2024-08-03 16:54:59.081 INFO booster.py:486 [alice] -- [Anonymous_job] level 2 time 14.805603981018066s
# 2024-08-03 16:55:18.937 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 19.85514521598816s
# 2024-08-03 16:55:28.552 INFO booster.py:486 [alice] -- [Anonymous_job] level 3 time 29.470705032348633s
# 2024-08-03 16:56:09.646 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 41.09283494949341s
# 2024-08-03 16:56:28.550 INFO booster.py:486 [alice] -- [Anonymous_job] level 4 time 59.99616456031799s
# 2024-08-03 16:56:29.050 WARNING callback.py:455 [alice] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:56:29.939 INFO booster.py:392 [alice] -- [Anonymous_job] epoch 8 time 119.27345418930054s
# 2024-08-03 16:56:30.502 INFO booster.py:375 [alice] -- [Anonymous_job] epoch 9 tree_setup time 0.562523603439331s
# 2024-08-03 16:56:35.707 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.198930978775024s
# 2024-08-03 16:56:37.531 INFO booster.py:486 [alice] -- [Anonymous_job] level 0 time 7.023317337036133s
# 2024-08-03 16:56:42.894 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 5.362109422683716s
# 2024-08-03 16:56:45.072 INFO booster.py:486 [alice] -- [Anonymous_job] level 1 time 7.539746046066284s
# 2024-08-03 16:56:55.004 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 9.93039345741272s
# 2024-08-03 16:56:59.611 INFO booster.py:486 [alice] -- [Anonymous_job] level 2 time 14.538108587265015s
# 2024-08-03 16:57:20.095 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 20.482851028442383s
# 2024-08-03 16:57:29.225 INFO booster.py:486 [alice] -- [Anonymous_job] level 3 time 29.6125271320343s
# 2024-08-03 16:58:09.707 INFO booster.py:426 [alice] -- [Anonymous_job] fragment[0, 0] gradient sum time 40.48050546646118s
# 2024-08-03 16:58:27.874 INFO booster.py:486 [alice] -- [Anonymous_job] level 4 time 58.64758586883545s
# 2024-08-03 16:58:28.494 WARNING callback.py:455 [alice] -- [Anonymous_job] no effective dump_function provided.
# 2024-08-03 16:58:28.565 INFO booster.py:392 [alice] -- [Anonymous_job] epoch 9 time 118.06139707565308s
# (_run pid=938515) INFO:jax._src.xla_bridge:Unable to initialize backend 'cuda':
# (_run pid=938515) INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# (_run pid=938515) INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# (_run pid=938515) [2024-08-03 16:38:27.228] [info] [thread_pool.cc:30] Create a fixed thread pool with size 7
# (SPURuntime(device_id=None, party=alice) pid=938424) 2024-08-03 16:38:33.670 [info] [thread_pool.cc:ThreadPool:30] Create a fixed thread pool with size 7
# (_run pid=938516) INFO:jax._src.xla_bridge:Unable to initialize backend 'cuda':
# (_run pid=938516) INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# (_run pid=938516) INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# (_run pid=938516) INFO:jax._src.xla_bridge:Unable to initialize backend 'interpreter': jaxlib.xla_extension.Client: no constructor defined!
# (XgbTreeWorker pid=938892) [2024-08-03 16:40:29.322] [info] [thread_pool.cc:30] Create a fixed thread pool with size 7
# (XgbTreeWorker pid=946529) [2024-08-03 16:59:47.761] [info] [thread_pool.cc:30] Create a fixed thread pool with size 7

# %% [markdown]
# ## 模型评估
#
# 现在我们可以将模型输出与真实标签进行比较。

# %%
yhat = model.predict(v_data)
yhat = reveal(yhat)
print(f"auc: {roc_auc_score(y, yhat)}")
# Out:
# 2024-08-03 16:59:45.982 INFO proxy.py:180 [alice] -- [Anonymous_job] Create proxy actor <class 'secretflow.ml.boost.ss_xgb_v.core.tree_worker.XgbTreeWorker'> with party alice.
# 2024-08-03 16:59:46.021 INFO proxy.py:180 [alice] -- [Anonymous_job] Create proxy actor <class 'secretflow.ml.boost.ss_xgb_v.core.tree_worker.XgbTreeWorker'> with party bob.
# auc: 1.0

# %% [markdown]
# ## 模型权重
#
# 现在我们可以将模型输出与真实标签进行比较。

# %%
a=sf.reveal(model.get_weights())
a
# Out:
# [array([[ 0.591123  ],
#         [ 0.3934378 ],
#         [ 0.        ],
#         [-0.42856592],
#         [ 0.5492958 ],
#         [-0.2727273 ],
#         [ 0.27272728],
#         [-0.44680843],
#         [ 0.5555502 ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.42856592],
#         [ 0.42856592],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.58973515],
#         [ 0.54545456],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.42856592],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.5624961 ],
#         [ 0.        ],
#         [-0.5985111 ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ]], dtype=float32),
#  array([[ 0.3981441 ],
#         [ 0.        ],
#         [-0.10535111],
#         [ 0.37898457],
#         [ 0.2834919 ],
#         [-0.5448195 ],
#         [-0.76084554],
#         [-0.38050643],
#         [ 0.36560106],
#         [ 0.        ],
#         [-0.2921255 ],
#         [ 0.        ],
#         [ 0.29212546],
#         [ 0.        ],
#         [-0.38877958],
#         [ 0.        ],
#         [ 0.34588653],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.37891412],
#         [ 0.        ],
#         [ 0.26710364],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.39509282]], dtype=float32),
#  array([[ 0.26718974],
#         [ 0.3500401 ],
#         [ 0.2988608 ],
#         [-0.37034643],
#         [ 0.        ],
#         [ 0.209736  ],
#         [ 0.        ],
#         [-0.32609916],
#         [ 0.26627415],
#         [ 0.        ],
#         [-1.0293983 ],
#         [-0.41387975],
#         [ 0.        ],
#         [-0.21890049],
#         [ 0.3311882 ],
#         [ 0.        ],
#         [ 0.35158712],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.25373688],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.51601195],
#         [ 0.        ],
#         [ 0.36787134],
#         [ 0.        ],
#         [-0.3201239 ],
#         [ 0.        ],
#         [-0.27821127],
#         [ 0.3063407 ],
#         [-0.8623687 ],
#         [-0.35644495]], dtype=float32),
#  array([[ 0.3332088 ],
#         [ 0.        ],
#         [ 0.33406582],
#         [-0.03938682],
#         [-0.38617912],
#         [ 0.        ],
#         [ 0.29911625],
#         [ 0.        ],
#         [ 0.27231467],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.32112342],
#         [ 0.        ],
#         [ 0.17797159],
#         [ 0.        ],
#         [ 0.3230602 ],
#         [ 0.        ],
#         [-0.22463126],
#         [ 0.        ],
#         [-0.34218898],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.32184315],
#         [ 0.        ],
#         [-0.29407328],
#         [ 0.        ],
#         [ 0.24765515],
#         [-0.30172214],
#         [ 0.        ],
#         [-0.34061396]], dtype=float32),
#  array([[ 0.32236063],
#         [ 0.        ],
#         [ 0.31805664],
#         [-0.11591591],
#         [ 0.        ],
#         [-0.29521984],
#         [ 0.24576254],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.19560583],
#         [ 0.        ],
#         [-0.5096166 ],
#         [ 0.33299682],
#         [ 0.        ],
#         [ 0.2488591 ],
#         [-0.23836315],
#         [ 0.30302256],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.2897985 ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.2214303 ],
#         [ 0.        ],
#         [-0.23860018],
#         [ 0.        ],
#         [ 0.28194898],
#         [ 0.2783103 ],
#         [-0.26931763],
#         [ 0.12951061],
#         [-0.325354  ]], dtype=float32),
#  array([[ 0.31500655],
#         [ 0.        ],
#         [ 0.30796462],
#         [-0.03488323],
#         [-0.28055716],
#         [ 0.11507557],
#         [ 0.27480602],
#         [-0.17984855],
#         [-0.032153  ],
#         [ 0.24848664],
#         [-0.23216924],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.25591332],
#         [ 0.19951227],
#         [-0.3240342 ],
#         [ 0.        ],
#         [ 0.25093687],
#         [ 0.        ],
#         [-0.1266432 ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.24221128],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.3130868 ],
#         [ 0.        ]], dtype=float32),
#  array([[ 0.31030503],
#         [ 0.08196747],
#         [ 0.        ],
#         [-0.14543784],
#         [ 0.30508298],
#         [ 0.        ],
#         [ 0.09824237],
#         [-1.0739944 ],
#         [ 0.28366417],
#         [ 0.        ],
#         [ 0.25681895],
#         [-0.1030097 ],
#         [ 0.23277362],
#         [-0.242273  ],
#         [ 0.0236219 ],
#         [-0.30008656],
#         [ 0.23082122],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.11732116],
#         [-0.22810535],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.30813575],
#         [ 0.        ],
#         [ 0.        ]], dtype=float32),
#  array([[ 0.30817574],
#         [ 0.        ],
#         [-0.22880454],
#         [ 0.2154033 ],
#         [ 0.28733182],
#         [ 0.        ],
#         [-0.43049678],
#         [ 0.08039601],
#         [ 0.20137362],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.0937544 ],
#         [-0.2583147 ],
#         [ 0.        ],
#         [ 0.13537171],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.37900987],
#         [ 0.29787055],
#         [ 0.        ],
#         [ 0.19497898],
#         [-0.19938886],
#         [ 0.        ],
#         [-0.18202381],
#         [ 0.        ],
#         [ 0.2048984 ],
#         [ 0.17127188],
#         [-0.12711516],
#         [-0.30196753],
#         [ 0.        ]], dtype=float32),
#  array([[ 0.30403554],
#         [ 0.        ],
#         [-0.2414328 ],
#         [ 0.21938673],
#         [ 0.07624964],
#         [-0.23797469],
#         [ 0.242425  ],
#         [-0.13473305],
#         [ 0.20791271],
#         [-0.07837531],
#         [-0.1877125 ],
#         [ 0.        ],
#         [ 0.20785634],
#         [ 0.        ],
#         [ 0.1441516 ],
#         [-0.2899298 ],
#         [ 0.        ],
#         [ 0.21458283],
#         [ 0.        ],
#         [-0.09764111],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.20386623],
#         [ 0.        ],
#         [-0.3013265 ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ]], dtype=float32),
#  array([[ 0.30259073],
#         [ 0.00066423],
#         [-0.18387267],
#         [ 0.18892273],
#         [ 0.2745835 ],
#         [ 0.        ],
#         [-0.3629639 ],
#         [ 0.18248284],
#         [ 0.23308651],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.1625843 ],
#         [ 0.        ],
#         [ 0.        ],
#         [-0.2600273 ],
#         [ 0.24127562],
#         [-0.07357024],
#         [-0.28496355],
#         [ 0.11374386],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.26348457],
#         [ 0.        ],
#         [ 0.20077303],
#         [ 0.        ],
#         [-0.20375805],
#         [ 0.        ],
#         [ 0.        ],
#         [ 0.11340426],
#         [-0.07324639],
#         [-0.30070984]], dtype=float32)]

# %%
import numpy as np

pd.DataFrame(np.array(a).reshape(-1, 32))
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.591123  0.393438  0.000000 -0.428566  0.549296 -0.272727  0.272727
# 1  0.398144  0.000000 -0.105351  0.378985  0.283492 -0.544819 -0.760846
# 2  0.267190  0.350040  0.298861 -0.370346  0.000000  0.209736  0.000000
# 3  0.333209  0.000000  0.334066 -0.039387 -0.386179  0.000000  0.299116
# 4  0.322361  0.000000  0.318057 -0.115916  0.000000 -0.295220  0.245763
# 5  0.315007  0.000000  0.307965 -0.034883 -0.280557  0.115076  0.274806
# 6  0.310305  0.081967  0.000000 -0.145438  0.305083  0.000000  0.098242
# 7  0.308176  0.000000 -0.228805  0.215403  0.287332  0.000000 -0.430497
# 8  0.304036  0.000000 -0.241433  0.219387  0.076250 -0.237975  0.242425
# 9  0.302591  0.000664 -0.183873  0.188923  0.274583  0.000000 -0.362964
#
#          7         8         9   ...        22        23        24        25  \
# 0 -0.446808  0.555550  0.000000  ...  0.000000 -0.562496  0.000000 -0.598511
# 1 -0.380506  0.365601  0.000000  ...  0.267104  0.000000  0.000000  0.000000
# 2 -0.326099  0.266274  0.000000  ... -0.516012  0.000000  0.367871  0.000000
# 3  0.000000  0.272315  0.000000  ...  0.000000  0.000000  0.321843  0.000000
# 4  0.000000  0.000000  0.195606  ...  0.000000  0.221430  0.000000 -0.238600
# 5 -0.179849 -0.032153  0.248487  ...  0.000000 -0.242211  0.000000  0.000000
# 6 -1.073994  0.283664  0.000000  ...  0.000000  0.000000  0.000000  0.000000
# 7  0.080396  0.201374  0.000000  ...  0.194979 -0.199389  0.000000 -0.182024
# 8 -0.134733  0.207913 -0.078375  ...  0.000000 -0.203866  0.000000 -0.301327
# 9  0.182483  0.233087  0.000000  ...  0.263485  0.000000  0.200773  0.000000
#
#          26        27        28        29        30        31
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000 -0.395093
# 2 -0.320124  0.000000 -0.278211  0.306341 -0.862369 -0.356445
# 3 -0.294073  0.000000  0.247655 -0.301722  0.000000 -0.340614
# 4  0.000000  0.281949  0.278310 -0.269318  0.129511 -0.325354
# 5  0.000000  0.000000  0.000000  0.000000 -0.313087  0.000000
# 6  0.000000  0.000000  0.000000 -0.308136  0.000000  0.000000
# 7  0.000000  0.204898  0.171272 -0.127115 -0.301968  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9 -0.203758  0.000000  0.000000  0.113404 -0.073246 -0.300710
#
# [10 rows x 32 columns]
