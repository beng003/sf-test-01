# %% [markdown]
# # Neural Network with SPU
#
# >  Please read lab [Logistic Regression On SPU](./lr_with_spu.ipynb) first if you have not。
#
# In lab [Logistic Regression On SPU](./lr_with_spu.ipynb), we have showed how to use SecretFlow/SPU to convert a plaintext JAX training program to a secure MPC training program.
#
# In this lab, the idea is quite similar but this time we will work with a Neural Network model.
#
# We are going to use the same dataset and all the settings as lab [Logistic Regression On SPU](./lr_with_spu.ipynb).
#
# And first, let's work out the plaintext model.

# %% [markdown]
# >The following codes are demos only. It's **NOT for production** due to system security concerns, please **DO NOT** use it directly in production.

# %% [markdown]
# > This tutorial needs more resources than 8c16g, which is the minimum requirement of SecretFlow.

# %% [markdown]
# ## Train a model with JAX/FLAX
#
# ### Load the Dataset
#
# The below is just copied from lab [Logistic Regression On SPU](./lr_with_spu.ipynb). I'm not going to explain again.

# %%
import sys

# !{sys.executable} -m pip install --upgrade flax
# Out:
# Requirement already satisfied: flax in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (0.6.0)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/flax/
# Collecting flax
#   Using cached flax-0.8.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from flax) (1.24.3)
# Requirement already satisfied: jax>=0.4.27 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from flax) (0.4.30)
# Requirement already satisfied: msgpack in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from flax) (1.0.8)
# Requirement already satisfied: optax in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from flax) (0.2.3)
# Collecting orbax-checkpoint (from flax)
#   Using cached orbax_checkpoint-0.5.23-py3-none-any.whl.metadata (1.8 kB)
# Collecting tensorstore (from flax)
#   Using cached tensorstore-0.1.63-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: rich>=11.1 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from flax) (11.2.0)
# Requirement already satisfied: typing-extensions>=4.2 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from flax) (4.12.2)
# Requirement already satisfied: PyYAML>=5.4.1 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from flax) (6.0.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from jax>=0.4.27->flax) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from jax>=0.4.27->flax) (0.4.0)
# Requirement already satisfied: opt-einsum in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from jax>=0.4.27->flax) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from jax>=0.4.27->flax) (1.14.0)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from rich>=11.1->flax) (0.4.6)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from rich>=11.1->flax) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from rich>=11.1->flax) (2.18.0)
# Requirement already satisfied: absl-py>=0.7.1 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from optax->flax) (2.1.0)
# Requirement already satisfied: chex>=0.1.86 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from optax->flax) (0.1.86)
# Requirement already satisfied: etils[epy] in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from optax->flax) (1.7.0)
# Requirement already satisfied: nest_asyncio in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from orbax-checkpoint->flax) (1.6.0)
# Requirement already satisfied: protobuf in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from orbax-checkpoint->flax) (4.25.3)
# Requirement already satisfied: toolz>=0.9.0 in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from chex>=0.1.86->optax->flax) (0.12.1)
# Requirement already satisfied: fsspec in /home/beng003/anaconda/envs/sf/lib/python3.10/site-packages (from etils[epath,epy]->orbax-checkpoint->flax) (2024.2.0)
# Collecting importlib_resources (from etils[epath,epy]->orbax-checkpoint->flax)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting zipp (from etils[epath,epy]->orbax-checkpoint->flax)
#   Using cached zipp-3.19.2-py3-none-any.whl.metadata (3.6 kB)
# Downloading flax-0.8.5-py3-none-any.whl (731 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.3/731.3 kB 18.4 kB/s eta 0:00:00a 0:00:02
# Downloading orbax_checkpoint-0.5.23-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.5/232.5 kB 419.7 kB/s eta 0:00:00a 0:00:01
# Downloading tensorstore-0.1.63-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 2.4 MB/s eta 0:00:0000:0100:01m
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Downloading zipp-3.19.2-py3-none-any.whl (9.0 kB)
# Installing collected packages: zipp, importlib_resources, tensorstore, orbax-checkpoint, flax
#   Attempting uninstall: flax
#     Found existing installation: flax 0.6.0
#     Uninstalling flax-0.6.0:
#       Successfully uninstalled flax-0.6.0
# Successfully installed flax-0.8.5 importlib_resources-6.4.0 orbax-checkpoint-0.5.23 tensorstore-0.1.63 zipp-3.19.2

# %%
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer


def breast_cancer(party_id=None, train: bool = True) -> (np.ndarray, np.ndarray):
    x, y = load_breast_cancer(return_X_y=True)
    x = (x - np.min(x)) / (np.max(x) - np.min(x))
    x_train, x_test, y_train, y_test = train_test_split(
        x, y, test_size=0.2, random_state=42
    )

    if train:
        if party_id:
            if party_id == 1:
                return x_train[:, :15], _
            else:
                return x_train[:, 15:], y_train
        else:
            return x_train, y_train
    else:
        return x_test, y_test

# %%
breast_cancer(1,True)
# Out:
# (array([[2.12247297e-03, 4.07381288e-03, 1.38199342e-02, ...,
#          4.43112365e-04, 4.15373766e-03, 2.24471086e-06],
#         [4.95768688e-03, 6.24588622e-03, 3.35448989e-02, ...,
#          1.03761166e-03, 1.91490362e-02, 9.99764927e-07],
#         [2.15632346e-03, 3.25811001e-03, 1.39163141e-02, ...,
#          6.13070052e-04, 5.52891396e-03, 2.05406676e-06],
#         ...,
#         [3.35919135e-03, 3.95392572e-03, 2.12270804e-02, ...,
#          1.98377997e-04, 2.53173484e-03, 8.20874471e-07],
#         [3.28631876e-03, 4.61212976e-03, 2.14198402e-02, ...,
#          3.76586742e-04, 4.43112365e-03, 1.24917724e-06],
#         [2.86318759e-03, 4.82369535e-03, 1.81523272e-02, ...,
#          2.78091208e-04, 3.45086977e-03, 1.19417019e-06]]),
#  '')

# %% [markdown]
# ### Define the Model
#
#
# We are going to use a 4-layer [MLP](https://en.wikipedia.org/wiki/Multilayer_perceptron) model with a [ReLU](https://en.wikipedia.org/wiki/Rectifier_(neural_networks)) activation function here.

# %%
from typing import Sequence
import flax.linen as nn


FEATURES = [30, 15, 8, 1]


class MLP(nn.Module):
    features: Sequence[int]

    @nn.compact
    def __call__(self, x):
        for feat in self.features[:-1]:
            x = nn.relu(nn.Dense(feat)(x))
        x = nn.Dense(self.features[-1])(x)
        return x

# %% [markdown]
# Then we define the training method here.

# %%
import jax.numpy as jnp
import jax


def predict(params, x):
    # TODO(junfeng): investigate why need to have a duplicated definition in notebook,
    # which is not the case in a normal python program.
    from typing import Sequence
    import flax.linen as nn

    FEATURES = [30, 15, 8, 1]

    class MLP(nn.Module):
        features: Sequence[int]

        @nn.compact
        def __call__(self, x):
            for feat in self.features[:-1]:
                x = nn.relu(nn.Dense(feat)(x))
            x = nn.Dense(self.features[-1])(x)
            return x

    return MLP(FEATURES).apply(params, x)


def loss_func(params, x, y):
    pred = predict(params, x)

    def mse(y, pred):
        def squared_error(y, y_pred):
            return jnp.multiply(y - y_pred, y - y_pred) / 2.0

        return jnp.mean(squared_error(y, pred))

    return mse(y, pred)


def train_auto_grad(x1, x2, y, params, n_batch=10, n_epochs=10, step_size=0.01):
    x = jnp.concatenate((x1, x2), axis=1)
    xs = jnp.array_split(x, len(x) / n_batch, axis=0)
    ys = jnp.array_split(y, len(y) / n_batch, axis=0)

    def body_fun(_, loop_carry):
        params = loop_carry
        for x, y in zip(xs, ys):
            _, grads = jax.value_and_grad(loss_func)(params, x, y)
            params = jax.tree_util.tree_map(
                lambda p, g: p - step_size * g, params, grads
            )
        return params

    params = jax.lax.fori_loop(0, n_epochs, body_fun, params)
    return params


def model_init(n_batch=10):
    model = MLP(FEATURES)
    return model.init(jax.random.PRNGKey(1), jnp.ones((n_batch, FEATURES[0])))

# %% [markdown]
# ### Validate the Model
#
# We use AUC as the validation metric.

# %%
from sklearn.metrics import roc_auc_score


def validate_model(params, X_test, y_test):
    y_pred = predict(params, X_test)
    return roc_auc_score(y_test, y_pred)

# %% [markdown]
# ### BUILD Together
#
# Let's put everything together and train a plaintext NN model!

# %%
import jax

# Load the data
x1, _ = breast_cancer(party_id=1, train=True)
x2, y = breast_cancer(party_id=2, train=True)


# Hyperparameter
n_batch = 10
n_epochs = 10
step_size = 0.01


# Train the model
init_params = model_init(n_batch)
params = train_auto_grad(x1, x2, y, init_params, n_batch, n_epochs, step_size)

# Test the model
X_test, y_test = breast_cancer(train=False)
auc = validate_model(params, X_test, y_test)
print(f'auc={auc}')
# Out:
# auc=0.9927939731411726

# %% [markdown]
# Must keep the number of AUC in mind, we are going to repeat the training with SPU. Let's do that magic!

# %% [markdown]
# ## Train a Model with SPU

# %%
import secretflow as sf

# Check the version of your SecretFlow
print('The version of SecretFlow: {}'.format(sf.__version__))

# In case you have a running secretflow runtime already.
sf.shutdown()

sf.init(['alice', 'bob'], address='local')

alice, bob = sf.PYU('alice'), sf.PYU('bob')
spu = sf.SPU(sf.utils.testing.cluster_def(['alice', 'bob']))

x1, _ = alice(breast_cancer)(party_id=1, train=True)
x2, y = bob(breast_cancer)(party_id=2, train=True)
init_params = model_init(n_batch)


device = spu
x1_, x2_, y_ = x1.to(device), x2.to(device), y.to(device)
init_params_ = sf.to(alice, init_params).to(device)

params_spu = spu(train_auto_grad, static_argnames=['n_batch', 'n_epochs', 'step_size'])(
    x1_, x2_, y_, init_params_, n_batch=n_batch, n_epochs=n_epochs, step_size=step_size
)
# Out:
# The version of SecretFlow: 1.8.0b0
# /home/beng003/anaconda/envs/sf/lib/python3.10/subprocess.py:1796: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = _posixsubprocess.fork_exec(
# 2024-07-28 18:42:00,793	INFO worker.py:1724 -- Started a local Ray instance.
# (_run pid=3552416) INFO:jax._src.xla_bridge:Unable to initialize backend 'cuda':
# (_run pid=3552416) INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# (_run pid=3552416) INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory
# (_run pid=3552420) INFO:jax._src.xla_bridge:Unable to initialize backend 'cuda':
# (_run pid=3552420) INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# (_run pid=3552420) INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: libtpu.so: cannot open shared object file: No such file or directory

# %% [markdown]
# Let's check params from SPU program.

# %%
params_spu = spu(train_auto_grad)(x1_, x2_, y_, init_params)
params = sf.reveal(params_spu)
print(params)
# Out:
# {'params': {'Dense_0': {'bias': array([ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, -8.4448457e-03,
#         4.7277704e-02,  3.7601590e-04,  0.0000000e+00,  4.5651197e-03,
#         0.0000000e+00, -3.4031868e-02, -8.4131658e-03,  0.0000000e+00,
#         0.0000000e+00,  5.6682825e-02, -4.8434734e-03,  0.0000000e+00,
#         3.5732180e-02,  6.3550323e-03,  2.9711276e-03,  3.2665536e-02,
#         0.0000000e+00, -2.1323681e-02, -7.8184158e-03,  0.0000000e+00,
#         2.8501868e-02,  0.0000000e+00, -3.0903667e-03,  3.8698316e-05,
#         1.4437318e-02,  2.0847723e-02], dtype=float32), 'kernel': array([[-0.14871399, -0.23531966, -0.1493772 , -0.01558939, -0.13323145,
#        [ 0.10726391,  0.15352644,  0.09634101,  0.01950403, -0.00730231,
#         -0.25290024, -0.2346187 ,  0.35619134,  0.17616235, -0.18047184,
#         -0.25238752, -0.05561563, -0.20358025, -0.13480256,  0.14421588],
#        [-0.32129213,  0.01505692,  0.32079336,  0.30846062,  0.06560674,
#         -0.20671532,  0.071106  ,  0.09106295, -0.05796376,  0.06883939,
#         -0.24341525,  0.09922644, -0.39771098, -0.14357334,  0.18188463],
#        [ 0.17828378, -0.3734979 , -0.34489787, -0.18513836, -0.12530549,
#         -0.3593558 , -0.21523722,  0.40664414, -0.06089024, -0.12822454,
#          0.30890357, -0.05408919,  0.1326272 ,  0.01791927,  0.22214782],
#        [-0.1597906 , -0.19275308, -0.3984378 , -0.13795093,  0.24811062,
#         -0.3026029 ,  0.25339967,  0.36626503, -0.04468067,  0.20680594,
#          0.10090984, -0.17185582, -0.0115933 ,  0.28760847,  0.07138817],
#        [-0.38753945, -0.21487817, -0.34942615, -0.3746059 ,  0.00249285,
#         -0.38013446, -0.26022446,  0.06026092, -0.05132058,  0.24081655,
#          0.20540601, -0.09037866, -0.16683164,  0.24142408, -0.26693594],
#        [-0.20973277, -0.0101587 ,  0.16557135,  0.20874728, -0.19013675,
#         -0.31780738, -0.03113298, -0.06459363,  0.39771876, -0.26641545,
#          0.3113753 , -0.06382816, -0.39697587,  0.10766909,  0.01153809],
#        [ 0.18971755,  0.02601419,  0.10644436, -0.21744527, -0.26413262,
#          0.15006723,  0.13827544, -0.21841142, -0.06611392,  0.2794575 ,
#         -0.10811286, -0.32185346, -0.03605992,  0.04212958, -0.01747663],
#        [ 0.04841596, -0.1742564 ,  0.12262946,  0.32726845, -0.08306259,
#         -0.3148705 ,  0.10644473,  0.09955123,  0.07176274, -0.20581172,
#          0.04141927, -0.00283223,  0.15970391,  0.19535124, -0.21868774],
#        [ 0.18083715,  0.09281985, -0.2790723 , -0.32184833,  0.08461116,
#         -0.13168146, -0.22216935,  0.06936353,  0.1084511 , -0.15438795,
#         -0.02530034,  0.03963596, -0.01773681,  0.04080661,  0.15702313],
#        [ 0.1722859 , -0.27421778,  0.03915337, -0.10644263,  0.15347561,
#         -0.4077602 , -0.14519483, -0.1972003 ,  0.15163714,  0.08711411,
#         -0.01810022,  0.03163131, -0.31662256, -0.08890386, -0.31581813],
#        [-0.09769943, -0.02877447,  0.3582303 , -0.27105692,  0.32774937,
#          0.08072284,  0.30246258, -0.192473  , -0.17831795,  0.29237264,
#          0.09354727, -0.25247368,  0.12927192,  0.38658625, -0.39495993],
#        [ 0.06277542,  0.08469242, -0.00951575,  0.10955815,  0.09936421,
#         -0.19083366,  0.21161576,  0.39304125,  0.00440572,  0.2008893 ,
#         -0.13770127,  0.27256176, -0.09585688, -0.05922091,  0.33084244]],
#       dtype=float32)}, 'Dense_2': {'bias': array([-0.01853444,  0.10750289,  0.        , -0.02408622,  0.10219099,
#         0.11779843, -0.0074137 ,  0.        ], dtype=float32), 'kernel': array([[ 1.70725226e-01, -9.90791917e-02, -2.29398310e-02,
#          1.22194618e-01, -1.06561974e-01, -3.67062837e-02,
#          1.41975164e-01,  8.84004533e-02],
#        [ 1.80475891e-01,  1.18611082e-01,  5.27172148e-01,
#         -1.53576508e-01, -3.86223197e-02, -1.22963876e-01,
#          6.26540184e-03,  1.59997195e-02],
#        [ 1.44997820e-01,  5.34002066e-01, -3.44355702e-01,
#         -9.43373740e-02,  1.35723814e-01, -8.21436942e-03,
#          1.19161353e-01, -4.11049873e-01],
#        [ 2.49562308e-01,  2.14895070e-01,  3.24747413e-01,
#         -4.91989821e-01, -1.14358604e-01, -2.11471766e-02,
#          7.69384056e-02,  3.31377953e-01],
#        [ 4.12400812e-02, -1.21448159e-01, -3.10940951e-01,
#          3.62135708e-01, -2.74279475e-01, -5.16959727e-01,
#         -5.41966408e-02,  5.59358776e-01],
#        [-4.59982008e-02, -6.31721616e-02,  1.12806559e-01,
#          3.72395188e-01,  1.19805992e-01,  2.30253160e-01,
#         -1.38900071e-01,  4.47024256e-02],
#        [-6.63793832e-02, -3.46704394e-01, -4.84587103e-01,
#          1.17089182e-01, -2.02461153e-01, -3.72340560e-01,
#          5.67471862e-01, -2.42814660e-01],
#        [ 3.36931914e-01, -1.21137410e-01,  3.77372414e-01,
#          4.15773451e-01,  4.28524911e-02, -3.28820914e-01,
#          4.96313632e-01, -1.31856978e-01],
#        [ 3.29437047e-01,  7.28742778e-02,  2.03800440e-01,
#          1.12697363e-01,  3.64428431e-01,  1.61251009e-01,
#         -2.09109098e-01,  5.50374389e-04],
#        [ 1.63456276e-01,  4.27290797e-04, -4.44933087e-01,
#         -9.06848758e-02,  3.35955709e-01,  4.89923298e-01,
#         -1.45878658e-01, -2.39348367e-01],
#        [-2.70905137e-01,  1.98488906e-01,  1.63834617e-01,
#         -3.97947073e-01,  8.93427432e-02,  3.55304182e-01,
#         -4.33428586e-03, -2.55934328e-01],
#        [ 2.71844625e-01, -6.50432259e-02,  5.75310588e-02,
#          8.60967785e-02,  4.62493598e-02,  6.84029907e-02,
#         -3.49441171e-01,  3.20650488e-01],
#        [ 3.87197286e-01,  1.02545783e-01, -3.67730916e-01,
#         -1.37638271e-01, -2.77009606e-03, -9.75389779e-03,
#         -2.03590691e-02, -3.78600478e-01],
#        [ 1.50329843e-01, -1.60096020e-01, -4.73224610e-01,
#          2.41277665e-01,  4.34345454e-02, -3.39222133e-01,
#          1.99609891e-01, -1.64232552e-01],
#        [-9.00832117e-02,  1.48897007e-01, -3.05355638e-02,
#          4.30267930e-01, -3.87655079e-01,  5.50715148e-01,
#         -9.88793969e-02, -3.92895550e-01]], dtype=float32)}, 'Dense_3': {'bias': array([0.23491548], dtype=float32), 'kernel': array([[-0.07592537],
#        [ 0.66343737],
#        [ 0.19396022],
#        [-0.21857144],
#        [ 0.447439  ],
#        [ 0.72588974],
#        [-0.07620344],
#        [-0.20487784]], dtype=float32)}}}

# %% [markdown]
# Lastly, let's validate the model.

# %%
X_test, y_test = breast_cancer(train=False)
auc = validate_model(params, X_test, y_test)
print(f'auc={auc}')
# Out:
# auc=0.9927939731411726

# %% [markdown]
# This is the end of the lab.
